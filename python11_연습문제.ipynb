# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.font_manager as fm
import pandas as pd

# %%
path = "C:\\Windows\\Fonts\\H2GPRM.TTF"
font_name = fm.FontProperties(fname=path).get_name()
rc('font',family=font_name)

# %%
file_path = './ref/train.csv'
data = pd.read_csv(file_path, encoding='EUC-KR')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# - 13번 문제

# %%
d_selected = data.iloc[:,[3,5]]
d_selected.head()
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %%
data1 = d_selected.groupby(['Name', 'Age']).sum().reset_index()
data1
# Out:
#                                              Name   Age
# 0                             Abbing, Mr. Anthony  42.0
# 1                     Abbott, Mr. Rossmore Edward  16.0
# 2                Abbott, Mrs. Stanton (Rosa Hunt)  35.0
# 3                             Abelson, Mr. Samuel  30.0
# 4           Abelson, Mrs. Samuel (Hannah Wizosky)  28.0
# ..                                            ...   ...
# 709  de Messemaeker, Mrs. Guillaume Joseph (Emma)  36.0
# 710                       de Mulder, Mr. Theodore  30.0
# 711                     de Pelsmaeker, Mr. Alfons  16.0
# 712                     del Carlo, Mr. Sebastiano  29.0
# 713               van Billiard, Mr. Austin Blyler  40.5
#
# [714 rows x 2 columns]

# %%
# data2 = data1['Age'] >= 60
# data2 = data2.sort_values(by = data1['Age'])
data2 = data1[data1['Age'] >= 60].sort_values(by='Name')
data2.head(3)
# Out:
#                                     Name   Age
# 33     Andrews, Miss. Kornelia Theodosia  63.0
# 39               Artagaveytia, Mr. Ramon  71.0
# 66  Barkworth, Mr. Algernon Henry Wilson  80.0

# %% [markdown]
# - 14번 문제

# %%
data3 = data[data['Survived'] == 1]
data3.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
d_selected1 = data3.iloc[:,[2,3,5]]
d_selected1.head()
# Out:
#    Pclass                                               Name   Age
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2       3                             Heikkinen, Miss. Laina  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9       2                Nasser, Mrs. Nicholas (Adele Achem)  14.0

# %% [markdown]
# - 15번 문제

# %%
data2 = data[data['Age'] >= 60]
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 33            34         0       2
# 54            55         0       1
# 96            97         0       1
# 116          117         0       3
# 170          171         0       1
# 252          253         0       1
# 275          276         1       1
# 280          281         0       3
# 326          327         0       3
# 366          367         1       1
# 438          439         0       1
# 456          457         0       1
# 483          484         1       3
# 493          494         0       1
# 545          546         0       1
# 555          556         0       1
# 570          571         1       2
# 587          588         1       1
# 625          626         0       1
# 630          631         1       1
# 672          673         0       2
# 684          685         0       2
# 694          695         0       1
# 745          746         0       1
# 829          830         1       1
# ...

# %%
data3 = data2[data2['Pclass'] == 1]
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 54            55         0       1
# 96            97         0       1
# 170          171         0       1
# 252          253         0       1
# 275          276         1       1
# 366          367         1       1
# 438          439         0       1
# 456          457         0       1
# 493          494         0       1
# 545          546         0       1
# 555          556         0       1
# 587          588         1       1
# 625          626         0       1
# 630          631         1       1
# 694          695         0       1
# 745          746         0       1
# 829          830         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 54                     Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 96                          Goldschmidt, Mr. George B    male  71.0      0
# 170                         Van der hoef, Mr. Wyckoff    male  61.0      0
# ...

# %%
data4 = data3[data3['Sex'] == 'female']
len(data4)
# Out:
# 3

# %% [markdown]
# - 16번 문제

# %%
d_selected2 = data.iloc[:,[1,2,4]]
d_selected2
# Out:
#      Survived  Pclass     Sex
# 0           0       3    male
# 1           1       1  female
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# ..        ...     ...     ...
# 886         0       2    male
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
# [891 rows x 3 columns]

# %%
# data5 = d_selected2[d_selected2['Sex'] == 'female'].sort_values(by=['Survived','Pclass'])
data5 = d_selected2[d_selected2['Sex'] == 'female'].groupby(['Pclass']).sum().reset_index()
data5
# Out:
#    Pclass  Survived                                                Sex
# 0       1        91  femalefemalefemalefemalefemalefemalefemalefema...
# 1       2        70  femalefemalefemalefemalefemalefemalefemalefema...
# 2       3        72  femalefemalefemalefemalefemalefemalefemalefema...

# %%
data6 = data5.sort_values(by='Pclass', ascending=True)
data6
# Out:
#    Pclass  Survived                                                Sex
# 0       1        91  femalefemalefemalefemalefemalefemalefemalefema...
# 1       2        70  femalefemalefemalefemalefemalefemalefemalefema...
# 2       3        72  femalefemalefemalefemalefemalefemalefemalefema...
