# %%
import pandas as pd
file_path = './ref/서울시 지하철 호선별 역별 시간대별 승하차 인원 정보2025.csv'
df = pd.read_csv(file_path, encoding='EUC-KR')
df.head(10) #데이터 5개 가져오기(데이터 잘 가져오나 확인하는 용도)
# df.tail()
# Out:
#       사용월  호선명          지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 0  202501  1호선           동대문           574            24          9298
# 1  202501  1호선           동묘앞           140             5          2218
# 2  202501  1호선           서울역           560            51          8353
# 3  202501  1호선            시청            89             0          1633
# 4  202501  1호선           신설동           362            10          7742
# 5  202501  1호선           제기동           305             1          4599
# 6  202501  1호선            종각           138             3          4176
# 7  202501  1호선          종로3가           140             9          3338
# 8  202501  1호선          종로5가            33             1          1504
# 9  202501  1호선  청량리(서울시립대입구)           830            15          8829
#
#    05시-06시 하차인원  06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  00시-01시 승차인원  \
# 0          1703          7860          5151         11813  ...           701
# 1           815          3245          4101          7160  ...           133
# 2          7685         20145         46128         61204  ...          4266
# 3          4268          3078         20969          6047  ...           429
# 4          1924          8178          6905         17444  ...           360
# 5          2124          7544          8403         18179  ...           189
# 6          4949          3897         28257          5592  ...          1714
# 7          2424          3227          9593          4432  ...          1378
# 8          2880          2611         12776          4801  ...           255
# 9          2757         14761          8484         39975  ...           308
#
#    00시-01시 하차인원  01시-02시 승차인원  01시-02시 하차인원  02시-03시 승차인원  02시-03시 하차인원  \
# 0          2571            12           217             0             0
# 1          1749             2           214             0             0
# 2          6765           239           237             0             0
# 3           811             9            24             0             0
# 4          2314             3            46             0             0
# 5          1381             8            49             0             0
# 6          1049            12            16             0             0
# 7          1692            14            38             0             0
# 8           809             0            21             0             0
# 9          3378             5            64             0             0
#
#    03시-04시 승차인원  03시-04시 하차인원      작업일자       합계
# 0             0             0  20250203   669467
# 1             0             0  20250203   564871
# 2             0             0  20250203  3641701
# 3             0             0  20250203  1403574
# 4             0             0  20250203   728346
# 5             0             0  20250203   990307
# 6             0             0  20250203  2013383
# 7             0             0  20250203  1332906
# 8             0             0  20250203  1227960
# 9             0             0  20250203  1272687
#
# [10 rows x 53 columns]

# %%
columns1 = ['mon', 'line', 'station']
time_col0 = [f'{i}-{i+1}h'for i in range(4,24)]
time_col1 = [f'{i}-{i+1}h'for i in range(4,24)]
time_col2 = [f'{y}-{y+1}h'for y in range(0,4)]
time_col3 = [f'{y}-{y+1}h'for y in range(0,4)]
columns = columns1 + time_col0 + time_col1+ time_col2+ time_col3 +['make']+['total']
df.columns = columns
# print(len(df.columns)) 53 
# print(len(columns))    53 
# df = df.iloc[:,:5]
df_selected = df.iloc[:, [0, 1, 2, -1]]
df_selected
# Out:
#         mon line station    total
# 0    202501  1호선     동대문   669467
# 1    202501  1호선     동묘앞   564871
# 2    202501  1호선     서울역  3641701
# 3    202501  1호선      시청  1403574
# 4    202501  1호선     신설동   728346
# ..      ...  ...     ...      ...
# 616  202501  중앙선      원덕    17402
# 617  202501  중앙선      중랑   287249
# 618  202501  중앙선      지평     2695
# 619  202501  중앙선      팔당    41050
# 620  202501  중앙선      회기  1241543
#
# [621 rows x 4 columns]

# %%
df_selected.head()
# Out:
#       mon line station    total
# 0  202501  1호선     동대문   669467
# 1  202501  1호선     동묘앞   564871
# 2  202501  1호선     서울역  3641701
# 3  202501  1호선      시청  1403574
# 4  202501  1호선     신설동   728346

# %%
data = df_selected.groupby(['mon', 'line', 'station']).sum().reset_index()
data
# Out:
#         mon line station    total
# 0    202501  1호선     동대문   669467
# 1    202501  1호선     동묘앞   564871
# 2    202501  1호선     서울역  3641701
# 3    202501  1호선      시청  1403574
# 4    202501  1호선     신설동   728346
# ..      ...  ...     ...      ...
# 616  202501  중앙선      원덕    17402
# 617  202501  중앙선      중랑   287249
# 618  202501  중앙선      지평     2695
# 619  202501  중앙선      팔당    41050
# 620  202501  중앙선      회기  1241543
#
# [621 rows x 4 columns]

# %%
gdata= data[['mon', 'line', 'station','total']]
gdata= gdata.sort_values(by=['station','mon'], ascending=[True,True])
gdata.tail(10)
# Out:
#         mon line      station    total
# 175  202501  5호선           화곡  1443310
# 213  202501  6호선  화랑대(서울여대입구)   513521
# 364  202501  경부선           화서   662799
# 592  202501  일산선           화정   932617
# 620  202501  중앙선           회기  1241543
# 397  202501  경원선           회룡   671480
# 119  202501  4호선    회현(남대문시장)  1402862
# 214  202501  6호선        효창공원앞   363492
# 427  202501  경의선        효창공원앞   170172
# 300  202501  9호선    흑석(중앙대입구)   461911

# %%
mdata = gdata.groupby(by='station').sum().reset_index()
tdata = mdata[['mon','line','station','total']]
tdata.tail(30)
# Out:
#         mon            line      station    total
# 498  202501             5호선        하남검단산   361084
# 499  202501             5호선  하남시청(덕풍?신장)   447665
# 500  202501             5호선         하남풍산   245643
# 501  202501             7호선           학동  1156537
# 502  202501             3호선          학여울   116871
# 503  202501             6호선          한강진   950223
# 504  202501             경의선        한국항공대    80818
# 505  202501             경원선           한남   224375
# 506  202501             안산선          한대앞   469433
# 507  202501             4호선   한성대입구(삼선교)   688865
# 508  202501        9호선2~3단계         한성백제   156198
# 509  202501             2호선          한양대   428393
# 510  202501             분당선           한티   874478
# 511  405002          2호선6호선           합정  2561363
# 512  202501             5호선           행당   399937
# 513  202501             경의선           행신   409023
# 514  202501             4호선           혜화  1970528
# 515  202501             수인선          호구포   197235
# 516  607503  2호선경의선공항철도 1호선         홍대입구  5245266
# 517  202501             3호선           홍제   913419
# 518  202501           우이신설선           화계   187372
# 519  202501             5호선           화곡  1443310
# 520  202501             6호선  화랑대(서울여대입구)   513521
# 521  202501             경부선           화서   662799
# 522  202501             일산선           화정   932617
# 523  202501             중앙선           회기  1241543
# 524  202501             경원선           회룡   671480
# 525  202501             4호선    회현(남대문시장)  1402862
# 526  405002          6호선경의선        효창공원앞   533664
# 527  202501             9호선    흑석(중앙대입구)   461911

# %%
sdata=tdata.sort_values(by='total', ascending=False)
sdata.head(10)
total_data = sdata[:30]
total_data
# Out:
#          mon                  line       station    total
# 250  1012505  1호선4호선경부선경의선공항철도 1호선           서울역  5892963
# 427   405002                2호선8호선      잠실(송파구청)  5350554
# 516   607503        2호선경의선공항철도 1호선          홍대입구  5245266
# 35    607503             3호선7호선9호선         고속터미널  4729132
# 11    202501                   2호선            강남  4264556
# 217   405002                2호선4호선            사당  3647446
# 260   405002                2호선분당선            선릉  3396103
# 308   405002                2호선신림선            신림  3083821
# 3     405002                7호선경부선       가산디지털단지  2999142
# 355   405002                5호선9호선           여의도  2958977
# 54    202501                   2호선       구로디지털단지  2955955
# 306   405002                2호선경부선           신도림  2911806
# 25    405002                2호선7호선          건대입구  2786537
# 444   607503             1호선3호선5호선          종로3가  2757136
# 225   202501                   2호선      삼성(무역센터)  2739577
# 288   405002                경부선분당선            수원  2711818
# 295   405002                1호선2호선            시청  2706942
# 358   202501                   2호선            역삼  2618006
# 406   202501                   2호선         을지로입구  2605643
# 511   405002                2호선6호선            합정  2561363
# 266   202501                   2호선            성수  2545701
# 388   202501                   경부선            용산  2520648
# 248   202501                   2호선   서울대입구(관악구청)  2392684
# 364   202501                   경부선           영등포  2361598
# 52    405002                2호선3호선    교대(법원.검찰청)  2343966
# 94    405002                4호선7호선            노원  2323193
# 474   405002                1호선경원선  청량리(서울시립대입구)  2280274
# 39    810004     5호선6호선경의선공항철도 1호선            공덕  2135882
# 469   405002                5호선8호선      천호(풍납토성)  2085518
# 320   405002                2호선경의선            신촌  2040162

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

d2_path = './ref/D2Coding-Ver1.3.2-20180524.ttf'
fm.fontManager.addfont(d2_path)
plt.rcParams['font.family'] = 'D2Coding'

# %%
import squarify
plt.figure(figsize=(15,10))
# squarify.plot(sizes=sdata['total'].iloc[:20],label=sdata['name'].iloc[:20])
# squarify.plot(sizes=total_data['total'],label=total_data['name'], alpha=0.5)
squarify.plot(sizes=total_data['total'], label= [f"{x[0]}({x[1]}명)" for x in zip(total_data['station'],total_data['total'])], alpha= 0.7)
plt.rcParams['font.size'] = 8
# plt.rcParams['text.color'] = 'black'
plt.gca().invert_yaxis()
plt.axis('off')
plt.show()
