# %%
# !pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting folium
#   Downloading folium-0.19.5-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in /home/pkdata/.local/lib/python3.10/site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /home/pkdata/.local/lib/python3.10/site-packages (from folium) (2.2.4)
# Requirement already satisfied: requests in /home/pkdata/.local/lib/python3.10/site-packages (from folium) (2.32.3)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2025.1.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/pkdata/.local/lib/python3.10/site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/pkdata/.local/lib/python3.10/site-packages (from requests->folium) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/pkdata/.local/lib/python3.10/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/pkdata/.local/lib/python3.10/site-packages (from requests->folium) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pkdata/.local/lib/python3.10/site-packages (from requests->folium) (2025.1.31)
# Downloading folium-0.19.5-py2.py3-none-any.whl (110 kB)
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading xyzservices-2025.1.0-py3-none-any.whl (88 kB)
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.8.1 folium-0.19.5 xyzservices-2025.1.0

# %%
import pandas as pd
import folium
file_path = 'ref/starbucks_20250411122227.csv'
data = pd.read_csv(file_path)
data = data[['이름','위도','경도','주소','타입']]
data.head()
# Out:
#         이름         위도          경도                                         주소  \
# 0  금정남산동DT  35.262179  129.091325         부산광역시 금정구 중앙대로 1989 (남산동)1522-3232
# 1   금정구청DT  35.238814  129.092986         부산광역시 금정구 중앙대로 1730 (부곡동)1522-3232
# 2   온천장역DT  35.224006  129.086560           부산광역시 금정구 식물원로 13 (장전동)1522-3232
# 3    부산대정문  35.232122  129.084496      부산광역시 금정구 부산대학로64번길 12 (장전동)1522-3232
# 4     부산대역  35.230522  129.088694  부산광역시 금정구 장전로12번길 64, 1~4층 (장전동)1522-3232
#
#               타입
# 0  pin_generalDT
# 1  pin_generalDT
# 2  pin_generalDT
# 3    pin_general
# 4    pin_general

# %%
fixdata = data[['이름','위도','경도']]
fixdata.head()
# Out:
#         이름         위도          경도
# 0  금정남산동DT  35.262179  129.091325
# 1   금정구청DT  35.238814  129.092986
# 2   온천장역DT  35.224006  129.086560
# 3    부산대정문  35.232122  129.084496
# 4     부산대역  35.230522  129.088694

# %%
coordinates = fixdata[['위도','경도']].to_numpy()
place = fixdata['이름'].to_numpy()

# 중심좌표 설정(기본위치)
center_lat, center_lon = 35.17574517, 129.0817409

# 지도생성
m = folium.Map(location=[center_lat, center_lon], zoom_start=12)
store_type = data['타입']

# lat, lon = coordinates[0]
for i, (lat, lon) in enumerate(coordinates):
    if store_type[i] == 'pin_generalDT':
        ccolor = 'blue'
        fcolor = 'white'
    elif store_type[i] == 'pin_general':
        ccolor = 'green'
        fcolor = 'white'
    else:
        ccolor = 'red'
        fcolor = 'white'
    folium.CircleMarker(
        location = [lat,lon],
        radius=10,
        color=ccolor,
        fill = True,
        fill_color = fcolor,
        fill_opacity = 1,
        tooltip = place[i]
    ).add_to(m) # 지도생성 후 원을 그리고 지도에 붙임

    folium.Marker(
        location = [lat + 0.001, lon],
        icon = folium.DivIcon(f'<div style="font-size: 9px; color:black; background-color: white; width:50px; white-space:nowrap; overflow:hidden; text-overflow:ellipsis; opacity:0.7; border-radius:5px">{place[i]}</div>')
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_299b6ad37efe018bb62fe670b8bd36d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_299b6ad37efe018bb62fe670b8bd36d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_299b6ad37efe018bb62fe670b8bd36d3 = L.map(
#                 &quot;map_299b6ad37efe018bb62fe670b8bd36d3&quot;,
#                 {
#                     center: [35.17574517, 129.0817409],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af59f108e03bdfae17a0779102c208b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af59f108e03bdfae17a0779102c208b9.addTo(map_299b6ad37efe018bb62fe670b8bd36d3);
#
#
#             var circle_marker_239c5bd4c34dc8c2ff214f22b70dab26 = L.circleMarker(
#                 [35.2621786292157, 129.091325043351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_299b6ad37efe018bb62fe670b8bd36d3);
#
#
#             circle_marker_239c5bd4c34dc8c2ff214f22b70dab26.bindTooltip(
#                 `&lt;div&gt;
#                      금정남산동DT
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_14cf1c7406cf20ac6f51e687ec88f1c0 = L.marker(
#                 [35.263178629215695, 129.091325043351],
#                 {
# }
#             ).addTo(map_299b6ad37efe018bb62fe670b8bd36d3);
#
#
#             var div_icon_c6bbc71dd55a151deafc0c9f05725c3f = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9px; color:black; background-color: white; width:50px; white-space:nowrap; overflow:hidden; text-overflow:ellipsis; opacity:0.7; border-radius:5px\&quot;\u003e\uae08\uc815\ub0a8\uc0b0\ub3d9DT\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_14cf1c7406cf20ac6f51e687ec88f1c0.setIcon(div_icon_c6bbc71dd55a151deafc0c9f05725c3f);
#
#
#                 marker_14cf1c7406cf20ac6f51e687ec88f1c0.setIcon(div_icon_c6bbc71dd55a151deafc0c9f05725c3f);
#
#
#             var circle_marker_4e0f10ecc8c606e2640fc0ae1ebfe155 = L.circleMarker(
#                 [35.2388135211636, 129.092985849499],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_299b6ad37efe018bb62fe670b8bd36d3);
#
#
#             circle_marker_4e0f10ecc8c606e2640fc0ae1ebfe155.bindTooltip(
#                 `&lt;div&gt;
#                      금정구청DT
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_cbcd9a5ad672251ec282caacc2eeeb05 = L.marker(
#                 [35.2398135211636, 129.092985849499],
#                 {
# }
#             ).addTo(map_299b6ad37efe018bb62fe670b8bd36d3);
#
#
#             var div_icon_736e9e8a8c1cac0794fdbdd67bb9fec0 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9px; color:black; background-color: white; width:50px; white-space:nowrap; overflow:hidden; text-overflow:ellipsis; opacity:0.7; border-radius:5px\&quot;\u003e\uae08\uc815\uad6c\uccadDT\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_cbcd9a5ad672251ec282caacc2eeeb05.setIcon(div_icon_736e9e8a8c1cac0794fdbdd67bb9fec0);
#
#
#                 marker_cbcd9a5ad672251ec282caacc2eeeb05.setIcon(div_icon_736e9e8a8c1cac0794fdbdd67bb9fec0);
#
#
#             var circle_marker_adef97ce17a42930e41e46385930ab3d = L.circleMarker(
#                 [35.224006, 129.08656],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;w
