# %%
# !pip install cx_Oracle 단종
# 기존방법
# import cx_Oracle
# dsc = cx_Oracle.makedsn('oracledb',1521,service_name='XEPDB1')
# conn = cx_Oracle.connect(user='pknu',password='1234',dsn=dsn)
# cursor = conn.cursor()

# %%
# !pip install oracledb # 고급기능은 thick 모드로 변경할 때 기존 cx_Oracle 버전처럼 instante_Client가 필요함
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: oracledb in /home/pkdata/.local/lib/python3.10/site-packages (3.1.0)
# Requirement already satisfied: cryptography>=3.2.1 in /home/pkdata/.local/lib/python3.10/site-packages (from oracledb) (44.0.2)
# Requirement already satisfied: cffi>=1.12 in /home/pkdata/.local/lib/python3.10/site-packages (from cryptography>=3.2.1->oracledb) (1.17.1)
# Requirement already satisfied: pycparser in /home/pkdata/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.2.1->oracledb) (2.22)

# %%
import oracledb
    # 데이터베이스 연결시도
try:
    conn = oracledb.connect(
        user='pknu',
        password='1234',
        dsn='oracle/XEPDB1'
    )
    print('Oracle 데이터베이스에 성공적으로 연결 되었습니다.')
except Exception as e:
    print('Oracle 데이터베이스 연결 실패:', e)
# Out:
# Oracle 데이터베이스에 성공적으로 연결 되었습니다.

# %%
# 테이블생성
query = """
    BEGIN
        EXCUTE IMMEDIATE'
            CREATE TABLE students(
                id NUMBER GENERATED BY DEFAULT AS IDENTITY PRIMARY KEY,
                name VARCHAR2(50),
                age NUMBER,
                email VARCHAR2(100)
            )';
    EXCEPTION
        WHEN OTHERS THEN
            IF SQLCODE != - 955 THEN
                RAISE;
            END IF;
        END;
"""
